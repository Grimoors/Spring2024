# %% [markdown]
# Install Prerequisites
#
# - Numpy
# - MNE

# %%
pip install numpy
# Out:
# ...
#   Obtaining dependency information for numpy from https://files.pythonhosted.org/packages/ad/11/52fbe97fd84c91105b651d25a122f8deed6d3519afb14f9771fac1c9b7de/numpy-1.26.3-cp312-cp312-win_amd64.whl.metadata
# ...
#      ---------------------------------------- 0.0/61.2 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/61.2 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/61.2 kB 330.3 kB/s eta 0:00:01
#      ------------------------------- ------ 51.2/61.2 kB 327.7 kB/s eta 0:00:01
#      -------------------------------------- 61.2/61.2 kB 364.1 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/15.5 MB ? eta -:--:--
#    ---------------------------------------- 0.1/15.5 MB 1.7 MB/s eta 0:00:10
#    ---------------------------------------- 0.1/15.5 MB 1.7 MB/s eta 0:00:09
#    ---------------------------------------- 0.2/15.5 MB 1.1 MB/s eta 0:00:14
#     --------------------------------------- 0.2/15.5 MB 1.4 MB/s eta 0:00:12
# ...

# %% [markdown]
# Import Dependencies and read raw data

# %%
import numpy as np
import mne.io 

edf_fname = "./datasets/neuro_kids_eeg_aws/ds004577-download/sub-NORB00001/ses-1/eeg/sub-NORB00001_ses-1_task-EEG_eeg.edf"

edf_raw = mne.io.read_raw_edf(edf_fname, preload=True)
hz = 1 / (edf_raw.times[1] - edf_raw.times[0])
# # If you wish to get specific channels and time:
# edf_data, times = edf_raw[channels_indices, int(from_t * hz): int(to_t * hz]
# Or to get all the data:
edf_data, times = edf_raw[:, :]

printf(edf_data)
printf(times)
# Out:
# Running cells with 'c:\ProgramData\chocolatey\bin\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/ProgramData/chocolatey/bin/python.exe -m pip install ipykernel -U --user --force-reinstall'
